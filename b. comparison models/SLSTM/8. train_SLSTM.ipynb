# %%
import numpy
import os
import tensorflow as tf
from main_new_SLSTM import train #n_words=100000,
from collections import defaultdict
# Out:
# /userhome/35/yqdeng/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /userhome/35/yqdeng/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /userhome/35/yqdeng/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
tf.reset_default_graph()

if __name__ == '__main__':
    ###########3 use abstract, not article
    model_name = 'results/'   #os.path.basename(os.path.dirname(os.path.realpath(__file__)))
    train(
    saveto           = './{}.npz'.format(model_name),
    reload_          = True,
    dim_word         = 300, # or 300 glove
    dim              = 300,
    patience         = 20,
    n_words          = 154000,  #s p500 46174 #ding 33976 40325
    clip_c           = 10.,
    lrate            = 0.0004,
    optimizer        = 'adam',
    maxlen           = None,
    batch_size       = 8,
    valid_batch_size = 8,
    dispFreq         = 100,
    validFreq        = int(1411/8+1),#s p500 1321 # ding 1426
    saveFreq         = int(1411/8+1),
    use_dropout      = True,
    verbose          = False,
    delay1           = 3,
    delay2           = 7,
    types            = 'abstract',
    cut_word         = 30,
    cut_sentence     = 30,
    cut_news         = 30,
    last_layer       = 'LSTM',
    CNN_filter       = 64,
    CNN_kernel       = 3,
    keep_prob        = 0.5,
    datasets         = ['news_set/train.csv',
                        'price_set/train_label.csv'],
    valid_datasets   = ['news_set/validate.csv',
                        'price_set/validate_label.csv'],
    test_datasets    = ['news_set/test.csv',
                        'price_set/test_label.csv'],
    #tech_data        = 'technical.csv',
    dictionary       = 'news_set/vocab_cased_abstract.pickle',
    embedding        = 'vectors.txt',
    wait_N           = 1
    )
# Out:
# WARNING:tensorflow:From /userhome/35/yqdeng/data/reuters_new/main_new_SLSTM.py:458: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /userhome/35/yqdeng/data/reuters_new/main_new_SLSTM.py:468: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /userhome/35/yqdeng/data/reuters_new/main_new_SLSTM.py:471: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /userhome/35/yqdeng/data/reuters_new/main_new_SLSTM.py:424: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From /userhome/35/yqdeng/data/reuters_new/main_new_SLSTM.py:434: bidirectional_dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...
