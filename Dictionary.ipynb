# %%
import pickle
#with open('vocab_cased_title.pickle','rb') as f:
with open('vocab_cased_title11.pickle','rb') as f:
    x = pickle.load(f)

# %%
print(x) #7633+1 = 7634  
#vocab_cased_title11.pickle   14286+1 = 14287
#vocab_cased_title1.pickle   59939
# Out:
# OrderedDict([('_PAD_', 0), ('_UNK_', 1), ('_BOS_', 2), ('_EOS_', 3), ('in', 4), ('on', 5), ('for', 6), ('america', 7), ('of', 8), ('says', 9), ('as', 10), ('report.', 11), ('billion', 12), ('Fed', 13), ('China', 14), ('with', 15), ('at', 16), ('sales', 17), ('profit', 18), ('may', 19), ('and', 20), ('sees', 21), ('up', 22), ('new', 23), ('over', 24), ('shares', 25), ('CEO', 26), ('after', 27), ('Wall', 28), ('by', 29), ('from', 30), ('Analysis:', 31), ('bank', 32), ('but', 33), ('not', 34), ('EU', 35), ('more', 36), ('Street', 37), ('a', 38), ('sources.', 39), ('GM', 40), ('oil', 41), ('million', 42), ('source.', 43), ('percent', 44), ('deal', 45), ('cut', 46), ('euro', 47), ('buy', 48), ('Factbox:', 49), ('Japan', 50), ('debt', 51), ('Bank', 52), ('deal.', 53), ('FACTBOX:', 54), ('be', 55), ('could', 56), ('no', 57), ('ECB', 58), ('growth', 59), ('Greek', 60), ('seen', 61), ('Instant', 62), ('banks', 63), ('rise', 64), ('Exclamericaive:', 65), ('percent.', 66), ('market', 67), ('zon
# ...

# %%
with open('vocab_cased_abstract.pickle','rb') as f1:
    x1 = pickle.load(f1)
print(x1)
# Out:
# OrderedDict([('_PAD_', 0), ('_UNK_', 1), ('_BOS_', 2), ('_EOS_', 3), ('.', 4), ('the', 5), ('to', 6), ('a', 7), ('in', 8), ('of', 9), ('s', 10), ('and', 11), ('xxx', 12), ('on', 13), ('for', 14), ('said', 15), ('as', 16), ('its', 17), ('inc', 18), ('reuters', 19), ('u', 20), ('that', 21), ('new', 22), ('by', 23), ('from', 24), ('it', 25), ('with', 26), ('is', 27), ('corp', 28), ('at', 29), ('will', 30), ('after', 31), ('year', 32), ('an', 33), ('co', 34), ('york', 35), ('t', 36), ('billion', 37), ('company', 38), ('bank', 39), ('n', 40), ('than', 41), ('percent', 42), ('more', 43), ('largest', 44), ('may', 45), ('group', 46), ('world', 47), ('has', 48), ('be', 49), ('sales', 50), ('low', 51), ('two', 52), ('million', 53), ('chief', 54), ('according', 55), ('was', 56), ('quarter', 57), ('fell', 58), ('are', 59), ('market', 60), ('biggest', 61), ('this', 62), ('government', 63), ('executive', 64), ('general', 65), ('month', 66), ('first', 67), ('about', 68), ('week', 69), ('apple', 70)
# ...

# %%
#7633 vs #14286

# %%
import pickle

with open('vocab_cased_abstract.pickle','rb') as f:
    y = pickle.load(f)

# %%
print(y) #14286
# Out:
# OrderedDict([('_PAD_', 0), ('_UNK_', 1), ('_BOS_', 2), ('_EOS_', 3), ('.', 4), ('the', 5), ('to', 6), ('a', 7), ('in', 8), ('of', 9), ('s', 10), ('and', 11), ('xxx', 12), ('on', 13), ('for', 14), ('said', 15), ('as', 16), ('its', 17), ('inc', 18), ('reuters', 19), ('u', 20), ('that', 21), ('new', 22), ('by', 23), ('from', 24), ('it', 25), ('with', 26), ('is', 27), ('corp', 28), ('at', 29), ('will', 30), ('after', 31), ('year', 32), ('an', 33), ('co', 34), ('york', 35), ('t', 36), ('billion', 37), ('company', 38), ('bank', 39), ('n', 40), ('than', 41), ('percent', 42), ('more', 43), ('largest', 44), ('may', 45), ('group', 46), ('world', 47), ('has', 48), ('be', 49), ('sales', 50), ('low', 51), ('two', 52), ('million', 53), ('chief', 54), ('according', 55), ('was', 56), ('quarter', 57), ('fell', 58), ('are', 59), ('market', 60), ('biggest', 61), ('this', 62), ('government', 63), ('executive', 64), ('general', 65), ('month', 66), ('first', 67), ('about', 68), ('week', 69), ('apple', 70)
# ...
