# %%
############# MIL-Repcnn  ###########    (除了data_iteratorMIL可用，main.py, train都改过不要用)
####### update 26/12/2020
################  改了参数1370/7634-->乱了， attention_v2变成attention_v1,  instance_prediction那步参数dim=150; Group_prediction那步参数为300
####### update 23/12/2020
##############改回原来参数;learningraye=0.1
####发现问题“test cost很大,有154...原来test cost只有1.43”  --换数据集？改了dict,n_words,int(1370/32+1),dim=100???  Test cost = 57.4439

# %%
import numpy
import os
import tensorflow as tf
from main_mil_repcnn import train
from collections import defaultdict
# Out:
# /userhome/35/yqdeng/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /userhome/35/yqdeng/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /userhome/35/yqdeng/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
tf.reset_default_graph()

if __name__ == '__main__':
    ############ use TITLE
    model_name = 'models/'   #os.path.basename(os.path.dirname(os.path.realpath(__file__)))
    train(
    saveto           = './{}.npz'.format(model_name),
    reload_          = False, #原来是true
    dim_word         = 100, # or 300 glove  
    dim              = 50,  #options['dim']*2 = nin
    patience         = 10,
    n_words          = 7634,  #22671
    clip_c           = 10.,
    lrate            = 0.1,#0.04
    optimizer        = 'adam',
    maxlen           = None,
    batch_size       = 32,
    valid_batch_size = 32,
    dispFreq         = 20,
    validFreq        = int(1370/32+1),#1411--sample次数
    saveFreq         = int(1370/32+1),
    use_dropout      = True,
    verbose          = False,
    types            = 'title',
    cut_word         = False,
    cut_news         = False,
    CNN_filter       = 64,
    keep_prob        = 0.5,
    datasets         = ['news_set/train(originalwrong).csv',
                        'price_set/train_label(original wrong).csv'],
    valid_datasets   = ['news_set/validate(originalwrong).csv',
                        'price_set/validate_label(original wrong).csv'],
    test_datasets    = ['news_set/test(originalwrong).csv',
                        'price_set/test_label(original wrong).csv'],
    dictionary       = 'news_set/vocab_cased_title.pickle',#'part_title_vocab.pickle',  #news_set/vocab_cased_title.pickle
    embedding        = "glove/glove.6B.100d.txt",
    wait_N           = 1   #可以变！！
    )
# Out:
# WARNING:tensorflow:From /userhome/35/yqdeng/data/reuters_new/main_mil_repcnn.py:109: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /userhome/35/yqdeng/data/reuters_new/main_mil_repcnn.py:164: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /userhome/35/yqdeng/data/reuters_new/main_mil_repcnn.py:165: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /userhome/35/yqdeng/data/reuters_new/main_mil_repcnn.py:190: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From /userhome/35/yqdeng/data/reuters_new/main_mil_repcnn.py:200: conv1d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv1D` instead.
# ...
